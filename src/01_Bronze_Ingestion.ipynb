# %%
from pyspark.sql.functions import *
df = spark.read.csv('/Volumes/workspace/ibm/sales_capstone_volume/sales_source_1500.csv', header=True, inferSchema=True)
print("Current user:")
spark.sql("SELECT current_user()").show()




df.write.mode('overwrite').saveAsTable('workspace.default.sales_bronze_capstone')
