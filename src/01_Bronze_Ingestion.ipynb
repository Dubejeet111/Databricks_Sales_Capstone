# %%
from pyspark.sql.functions import *
df = spark.read.csv('/Workspace/Users/dubejeet111@gmail.com/Databricks_Sales_Capstone/data/sales_source_1500.csv', header=True, inferSchema=True)
df.printSchema()

df.write.mode('overwrite').saveAsTable('workspace.ibm.sales_bronze_capstone')
